# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyasri-1323/NLP-LAB/blob/main/Assignment_8_8_25_1323.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download('stopwords')

sentence =" the lion roars loudly in the forest at night always."

token=word_tokenize(sentence)
print("Tokens: ",token)
stop_words=set(stopwords.words("english"))
filtered_tokens=[word for word in token if word.lower() not in stop_words]
print("Filtered Token: ",filtered_tokens)
# Out:
# Tokens:  ['the', 'lion', 'roars', 'loudly', 'in', 'the', 'forest', 'at', 'night', 'always', '.']
# Filtered Token:  ['lion', 'roars', 'loudly', 'forest', 'night', 'always', '.']
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
nltk.download('wordnet')
sentence="The lion roars loudly in the forest at night always."

token=word_tokenize(sentence)
print(token)
stemmer=PorterStemmer()
Stemmer_tokens=[stemmer.stem(word) for word in token]
print(Stemmer_tokens)
# Out:
# ['The', 'lion', 'roars', 'loudly', 'in', 'the', 'forest', 'at', 'night', 'always', '.']
# ['the', 'lion', 'roar', 'loudli', 'in', 'the', 'forest', 'at', 'night', 'alway', '.']
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')

sentence =" the lion roars loudly in the forest at night always."

token=word_tokenize(sentence)
print("Tokens: ",token)
Lemmatizer=WordNetLemmatizer()
L_Tokens=[Lemmatizer.lemmatize(word) for word in token]
print("Lemmaword is :",L_Tokens)
# Out:
# Tokens:  ['the', 'lion', 'roars', 'loudly', 'in', 'the', 'forest', 'at', 'night', 'always', '.']
# Lemmaword is : ['the', 'lion', 'roar', 'loudly', 'in', 'the', 'forest', 'at', 'night', 'always', '.']
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
